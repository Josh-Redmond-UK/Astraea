# %%
import ee

from date_time_utils import *
from download_utils import *
from earth_engine_utils import *

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=I8LF7BtDsxvnZMDgxfKJW0D50WlMJcb7jBRwyqdU_hk&tc=MIp3IcN27F13h6eiigtwvfCiYfxTxYbjG96OepfyOJE&cc=yb9jWIthbJXEvXYt5xQRewTCs2lktl9KIDzlw_PEDaA>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=I8LF7BtDsxvnZMDgxfKJW0D50WlMJcb7jBRwyqdU_hk&tc=MIp3IcN27F13h6eiigtwvfCiYfxTxYbjG96OepfyOJE&cc=yb9jWIthbJXEvXYt5xQRewTCs2lktl9KIDzlw_PEDaA</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AfJohXnInc2V4oE8PoPkwddX2ykz6smELMnruezHJmRFZoPw0r9V0VyJAIs
# ...

# %%
testGeom = ee.Geometry.Rectangle([-98.95, 19.34, -98.94, 19.35]);

# %%
testColl = get_images_for_extent(testGeom, "2021-01-01", "2021-04-01", 100, "NDVI")

# %%
testColl.getInfo()
# Out:
# {'type': 'ImageCollection',
#  'bands': [],
#  'id': 'COPERNICUS/S2_SR',
#  'version': 1704361725085048,
#  'properties': {'date_range': [1490659200000, 1647907200000],
#   'period': 0,
#   'system:visualization_0_min': '0.0',
#   'type_name': 'ImageCollection',
#   'keywords': ['copernicus',
#    'esa',
#    'eu',
#    'msi',
#    'reflectance',
#    'sentinel',
#    'sr'],
#   'system:visualization_0_bands': 'B4,B3,B2',
#   'thumb': 'https://mw1.google.com/ges/dd/images/COPERNICUS_S2_SR_thumb.png',
# ...
